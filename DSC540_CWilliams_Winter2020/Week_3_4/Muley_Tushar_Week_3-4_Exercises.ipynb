# %% [markdown]
# Name: Muley, Tushar
#
# Assignment: Week 3 & 4 Exercises
#
# Date: January 10, 2021

# %% [markdown]
# # Exercise 1: Data Wrangling with Python: Activity 5, page 116

# %% [markdown]
# 1. Load the necessary libraries.

# %%
#Import my packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Read in the Boston housing dataset (given as a .csv file) from the local directory.

# %%
#Load Boston Housing data
df_boston=pd.read_csv('Boston_housing.csv')

# %%
#View the data to confirm I have it
df_boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %% [markdown]
# What all the variables mean:
#
#     CRIM - per capita crime rate by town
#     ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#     INDUS - proportion of non-retail business acres per town.
#     CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#     NOX - nitric oxides concentration (parts per 10 million)
#     RM - average number of rooms per dwelling
#     AGE - proportion of owner-occupied units built prior to 1940
#     DIS - weighted distances to five Boston employment centres
#     RAD - index of accessibility to radial highways
#     TAX - full-value property-tax rate per $10,000
#     PTRATIO - pupil-teacher ratio by town
#     B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#     LSTAT - % lower status of the population
#     MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# 3. Check the first 10 records. Find the total number of records.

# %%
print('First 10 records:\n',df_boston.head(10))
# Out:
# First 10 records:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# ...

# %%
print('Total record count:\n',df_boston.shape)
# Out:
# Total record count:
#  (506, 14)

# %% [markdown]
# 4. Create a smaller DataFrame with columns that do not include CHAS, NOX, B, and LSTAT.

# %%
df_smaller_boston=df_boston[['CRIM','ZN','INDUS','RM','AGE','DIS','RAD','TAX','PTRATIO','PRICE']]

# %%
#View the top 3 rows to make sure CHAS,NOX,B and LSTAT have been removed
df_smaller_boston.head(3)
# Out:
#       CRIM    ZN  INDUS     RM   AGE     DIS  RAD  TAX  PTRATIO  PRICE
# 0  0.00632  18.0   2.31  6.575  65.2  4.0900    1  296     15.3   24.0
# 1  0.02731   0.0   7.07  6.421  78.9  4.9671    2  242     17.8   21.6
# 2  0.02729   0.0   7.07  7.185  61.1  4.9671    2  242     17.8   34.7

# %% [markdown]
# 5. Check the last seven records of the new DataFrame you just created.

# %%
df_smaller_boston.tail(7) #Last 7 rows of smaller bostom DataFrame
# Out:
#         CRIM   ZN  INDUS     RM   AGE     DIS  RAD  TAX  PTRATIO  PRICE
# 499  0.17783  0.0   9.69  5.569  73.5  2.3999    6  391     19.2   17.5
# 500  0.22438  0.0   9.69  6.027  79.7  2.4982    6  391     19.2   16.8
# 501  0.06263  0.0  11.93  6.593  69.1  2.4786    1  273     21.0   22.4
# 502  0.04527  0.0  11.93  6.120  76.7  2.2875    1  273     21.0   20.6
# 503  0.06076  0.0  11.93  6.976  91.0  2.1675    1  273     21.0   23.9
# 504  0.10959  0.0  11.93  6.794  89.3  2.3889    1  273     21.0   22.0
# 505  0.04741  0.0  11.93  6.030  80.8  2.5050    1  273     21.0   11.9

# %% [markdown]
# 6. Plot the histograms of all the variables (columns) in the new DataFrame.

# %%
df_smaller_boston.hist() #plot the histograms
plt.show() #Show the histograms

# %% [markdown]
# 7. Plot them all at once using a for loop. Try to add a unique title to a plot.

# %%
#Start loop
for col in df_smaller_boston.columns: #Counter of columns in smaller boston DataFrame
    plt.hist(df_smaller_boston[col],bins=15) #Plot the histogram
    plt.title('Histogram of '+col) #Title the histogram
    plt.show() #Show the histogrm

# %% [markdown]
# 8.Create a scatter plot of crime rate versus price.

# %%
#Set the scatter plot
plt.scatter(df_smaller_boston.CRIM,df_smaller_boston.PRICE)
plt.title('Scatter plot of Crime rate vs. Home Price') #Title of plot
plt.xlabel('Crime',fontsize=12) #Label of X axis
plt.ylabel('Price',fontsize=12) #Label of Y axis
plt.show() #Show plot

# %% [markdown]
# 9.Plot using log10(crime) versus price.

# %%
plt.scatter(np.log10(df_smaller_boston.CRIM),df_smaller_boston.PRICE,c='green')
plt.title('Scatter plot of Crime (Log10) rate vs. Home Price') #Title of plot
plt.xlabel('Crime (Log10)',fontsize=12) #Label of X axis
plt.ylabel('Price',fontsize=12) #Label of Y axis
plt.show() #Show plot

# %% [markdown]
# 10.Calculate some useful statistics, such as mean rooms per dwelling, median age, mean distances to five Boston employment centers, and the percentage of houses with a low price (< $20,000).

# %%
#Mean of rooms per dwelling
#RM - average number of rooms per dwelling
print('Mean of Rooms per dwelling:\n',df_smaller_boston.RM.mean())
# Out:
# Mean of Rooms per dwelling:
#  6.284634387351788

# %%
#Median Age
#AGE - proportion of owner-occupied units built prior to 1940
print('Median of Age:\n',df_smaller_boston.AGE.median())
# Out:
# Median of Age:
#  77.5

# %%
#Mean of distance to five Boston employment centers
#DIS - weighted distances to five Boston employment centres
print('Distance to five Boston employment centers:\n',df_smaller_boston.DIS.mean())
# Out:
# Distance to five Boston employment centers:
#  3.795042687747034

# %%
df_less_20k=df_smaller_boston[df_smaller_boston['PRICE']<20.0]

# %%
#Percentage of houses with a low price (<$20,000)
# Add a new column named 'Price_less_20' 
df_smaller_boston['PRICE_LESS_20']=[1 if p <20.0 else 0 for p in df_smaller_boston['PRICE']]

df_smaller_boston.head
# Out:
# <ipython-input-17-052d4b9a771f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_smaller_boston['PRICE_LESS_20']=[1 if p <20.0 else 0 for p in df_smaller_boston['PRICE']]
# <bound method NDFrame.head of         CRIM    ZN  INDUS     RM   AGE     DIS  RAD  TAX  PTRATIO  PRICE  \
# 0    0.00632  18.0   2.31  6.575  65.2  4.0900    1  296     15.3   24.0
# 1    0.02731   0.0   7.07  6.421  78.9  4.9671    2  242     17.8   21.6
# 2    0.02729   0.0   7.07  7.185  61.1  4.9671    2  242     17.8   34.7
# 3    0.03237   0.0   2.18  6.998  45.8  6.0622    3  222     18.7   33.4
# 4    0.06905   0.0   2.18  7.147  54.2  6.0622    3  222     18.7   36.2
# ..       ...   ...    ...    ...   ...     ...  ...  ...      ...    ...
# ...

# %%
print('Percentage of homes priced less $20,000:\n',df_smaller_boston['PRICE_LESS_20'].mean()*100)
# Out:
# Percentage of homes priced less $20,000:
#  41.50197628458498

# %% [markdown]
# # Exercise 2: Data Wrangling with Python: Activity 6, page 171

# %% [markdown]
# 1.Load the necessary libraries.

# %%
#These were loaded as part of Activity 5 but reload as part of step 1.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2.Read the adult income dataset from the following URL: https://github.com/TrainingByPackt/Data-Wrangling-with-Python/blob/master/Chapter04/Activity06/.

# %%
#Load adult income data
df_adult_data = pd.read_csv('adult_income_data.csv')

# %%
df_adult_data.head()
# Out:
#    39          State-gov   77516   Bachelors  13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 1  38            Private  215646     HS-grad   9             Divorced
# 2  53            Private  234721        11th   7   Married-civ-spouse
# 3  28            Private  338409   Bachelors  13   Married-civ-spouse
# 4  37            Private  284582     Masters  14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family     Male  2174  0  40   United-States  \
# 0     Exec-managerial         Husband     Male     0  0  13   United-States
# 1   Handlers-cleaners   Not-in-family     Male     0  0  40   United-States
# 2   Handlers-cleaners         Husband     Male     0  0  40   United-States
# 3      Prof-specialty            Wife   Female     0  0  40            Cuba
# 4     Exec-managerial            Wife   Female     0  0  40   United-States
#
#     <=50K
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %% [markdown]
# 3.Create a script that will read a text file line by line.

# %%
df_adult_data_names = [] #Declare an empty list
with open('adult_income_names.txt','r') as file: #Open the file
    for line in file: #Loop through the file
        file.readline() #Read the line
        var=line.split(":")[0] #Split the file by colon
        df_adult_data_names.append(var) #Append the list

# %%
#Print the list
df_adult_data_names
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country']

# %% [markdown]
# 4.Add a name of Income for the response variable to the dataset.

# %%
df_adult_data_names.append('Income') #Append Income to DataFrame

# %%
#Print DataFrame
df_adult_data_names
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'Income']

# %%
#Added Names to Adult DataFrame to get column headers
df_adult_combined = pd.read_csv('adult_income_data.csv',names=df_adult_data_names)
df_adult_combined.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship      sex  \
# 0        Never-married        Adm-clerical   Not-in-family     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
#Visual compare "missing" values. There are question marks '?' in place of missing values.
df_adult_combined[df_adult_combined['native-country']==' ?']
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 14      40            Private  121772      Assoc-voc             11
# 38      31            Private   84154   Some-college             10
# 51      18            Private  226956        HS-grad              9
# 61      32                  ?  293936        7th-8th              4
# 93      30            Private  117747        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32449   44       Self-emp-inc   71556        Masters             14
# 32469   58       Self-emp-inc  181974      Doctorate             16
# 32492   42   Self-emp-not-inc  217597        HS-grad              9
# 32510   39            Private  107302        HS-grad              9
# 32525   81                  ?  120478      Assoc-voc             11
#
#                marital-status       occupation    relationship      sex  \
# 14         Married-civ-spouse     Craft-repair         Husband     Male
# ...

# %%
#Replace ' ?' with NaN for missing data.
df_adult=df_adult_combined.replace(' ?', np.NaN)

# %%
#Double check '?' are gone.
df_adult[df_adult['native-country']==' ?']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, sex, capital-gain, capital-loss, hours-per-week, native-country, Income]
# Index: []

# %%
df_adult.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship      sex  \
# 0        Never-married        Adm-clerical   Not-in-family     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df_adult.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'Income'],
#       dtype='object')

# %% [markdown]
# 5.Find the missing values.

# %%
df_adult.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# Income               0
# dtype: int64

# %% [markdown]
# 6.Create a DataFrame with only age, education, and occupation by using subsetting.

# %%
df_subset_adult = df_adult[['age','education','occupation']] #Create subset df with only 3 columns

df_subset_adult #Print df subset
# Out:
#        age    education          occupation
# 0       39    Bachelors        Adm-clerical
# 1       50    Bachelors     Exec-managerial
# 2       38      HS-grad   Handlers-cleaners
# 3       53         11th   Handlers-cleaners
# 4       28    Bachelors      Prof-specialty
# ...    ...          ...                 ...
# 32556   27   Assoc-acdm        Tech-support
# 32557   40      HS-grad   Machine-op-inspct
# 32558   58      HS-grad        Adm-clerical
# 32559   22      HS-grad        Adm-clerical
# 32560   52      HS-grad     Exec-managerial
#
# [32561 rows x 3 columns]

# %% [markdown]
# 7.Plot a histogram of age with a bin size of 20.

# %%
plt.hist(df_subset_adult['age'],bins=20) #Type of plot and bin setting
plt.title('Histogram of Age') #Title of plot
plt.xlabel('Age',fontsize=12) #Label of X axis
plt.ylabel('Frequency',fontsize=12) #Label of Y axis
plt.show() #Show plot

# %% [markdown]
# 8.Create a function to strip the whitespace characters.

# %%
#Function to strip leading and trailing whitespace.
#def remove_whitespace(data): #Function Name
#    return data.strip() #Function return

def remove_whitespace(strr):
    return strr.strip()

# %% [markdown]
# 9.Use the apply method to apply this function to all the columns with string values, create a new column, copy the values from this new column to the old column, and drop the new column.

# %%
# Remove whitespace from Education Column
df_subset_adult['education_wsr']=df_subset_adult['education'].apply(remove_whitespace)
# Out:
# <ipython-input-33-7d1f802d1321>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset_adult['education_wsr']=df_subset_adult['education'].apply(remove_whitespace)

# %%
#Print to confirm duplication and whitespace removed
df_subset_adult
# Out:
#        age    education          occupation education_wsr
# 0       39    Bachelors        Adm-clerical     Bachelors
# 1       50    Bachelors     Exec-managerial     Bachelors
# 2       38      HS-grad   Handlers-cleaners       HS-grad
# 3       53         11th   Handlers-cleaners          11th
# 4       28    Bachelors      Prof-specialty     Bachelors
# ...    ...          ...                 ...           ...
# 32556   27   Assoc-acdm        Tech-support    Assoc-acdm
# 32557   40      HS-grad   Machine-op-inspct       HS-grad
# 32558   58      HS-grad        Adm-clerical       HS-grad
# 32559   22      HS-grad        Adm-clerical       HS-grad
# 32560   52      HS-grad     Exec-managerial       HS-grad
#
# [32561 rows x 4 columns]

# %%
#Set Education equal to education whitespace removed
df_subset_adult['education']=df_subset_adult['education_wsr']
# Out:
# <ipython-input-35-e504982423b8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset_adult['education']=df_subset_adult['education_wsr']

# %%
#Confirm replacement
df_subset_adult
# Out:
#        age   education          occupation education_wsr
# 0       39   Bachelors        Adm-clerical     Bachelors
# 1       50   Bachelors     Exec-managerial     Bachelors
# 2       38     HS-grad   Handlers-cleaners       HS-grad
# 3       53        11th   Handlers-cleaners          11th
# 4       28   Bachelors      Prof-specialty     Bachelors
# ...    ...         ...                 ...           ...
# 32556   27  Assoc-acdm        Tech-support    Assoc-acdm
# 32557   40     HS-grad   Machine-op-inspct       HS-grad
# 32558   58     HS-grad        Adm-clerical       HS-grad
# 32559   22     HS-grad        Adm-clerical       HS-grad
# 32560   52     HS-grad     Exec-managerial       HS-grad
#
# [32561 rows x 4 columns]

# %%
#Drop education whitespace removed column
df_subset_adult.drop(labels=['education_wsr'],axis=1,inplace=True)
# Out:
# C:\Users\Tushar\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#Confirm education_wsr has been dropped
df_subset_adult.head(10)
# Out:
#    age  education          occupation
# 0   39  Bachelors        Adm-clerical
# 1   50  Bachelors     Exec-managerial
# 2   38    HS-grad   Handlers-cleaners
# 3   53       11th   Handlers-cleaners
# 4   28  Bachelors      Prof-specialty
# 5   37    Masters     Exec-managerial
# 6   49        9th       Other-service
# 7   52    HS-grad     Exec-managerial
# 8   31    Masters      Prof-specialty
# 9   42  Bachelors     Exec-managerial

# %%
#Remove whitespace from Occupation column
df_subset_adult['occupation_wsr']=df_subset_adult['occupation'].apply(remove_whitespace) #Removed whitespace
df_subset_adult['occupation']=df_subset_adult['occupation_wsr'] #Set occ_wsr to original occ
df_subset_adult.drop(labels=['occupation_wsr'],axis=1,inplace=True) #Drop occ_wsr
df_subset_adult.head(10) #Review table
# Out:
# <ipython-input-39-e336af0a2040>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset_adult['occupation_wsr']=df_subset_adult['occupation'].apply(remove_whitespace) #Removed whitespace
# <ipython-input-39-e336af0a2040>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset_adult['occupation']=df_subset_adult['occupation_wsr'] #Set occ_wsr to original occ
# C:\Users\Tushar\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# ...

# %% [markdown]
# 10.Find the number of people who are aged between 30 and 50

# %%
#Create a df with people from 30 to 50
by_age=df_subset_adult[(df_subset_adult['age']>=30) & (df_subset_adult['age']<=50)]

# %%
print('Count of people between 30 and 50',len(by_age))
# Out:
# Count of people between 30 and 50 16390

# %% [markdown]
# 11.Group the records based on age and education to find how the mean age is distributed.

# %%
#Group by age and education

df_subset_adult.groupby(['education']).mean()['age']
# Out:
# education
#  10th            37.429796
#  11th            32.355745
#  12th            32.000000
#  1st-4th         46.142857
#  5th-6th         42.885886
#  7th-8th         48.445820
#  9th             41.060311
#  Assoc-acdm      37.381443
#  Assoc-voc       38.553546
#  Bachelors       38.904949
#  Doctorate       47.702179
#  HS-grad         38.974479
#  Masters         44.049913
#  Preschool       42.764706
#  Prof-school     44.746528
#  Some-college    35.756275
# Name: age, dtype: float64

# %%
df_subset_adult.groupby(['age','education']).describe()
# Out:
#                   occupation
#                        count unique               top freq
# age education
# 17   10th                106     10     Other-service   56
#      11th                155     11             Sales   44
#      12th                 33      5     Other-service   13
#      5th-6th               1      1     Other-service    1
#      7th-8th               3      3   Farming-fishing    1
# ...                      ...    ...               ...  ...
# 90   Bachelors             8      3    Prof-specialty    3
#      HS-grad              11      6     Other-service    4
#      Masters               4      2   Exec-managerial    3
#      Prof-school           1      1    Prof-specialty    1
#      Some-college          5      4     Other-service    2
#
# [965 rows x 4 columns]

# %% [markdown]
# 12.Group by occupation and show the summary statistics of age. Find which profession has the oldest workers on average and which profession has its largest share of the workforce above the 75th percentile.

# %%
df_subset_adult.groupby('occupation').describe()['age']
# Out:
#                      count       mean        std   min   25%   50%   75%   max
# occupation
#  Adm-clerical       3770.0  36.964456  13.362998  17.0  26.0  35.0  46.0  90.0
#  Armed-Forces          9.0  30.222222   8.089774  23.0  24.0  29.0  34.0  46.0
#  Craft-repair       4099.0  39.031471  11.606436  17.0  30.0  38.0  47.0  90.0
#  Exec-managerial    4066.0  42.169208  11.974548  17.0  33.0  41.0  50.0  90.0
#  Farming-fishing     994.0  41.211268  15.070283  17.0  29.0  39.0  52.0  90.0
#  Handlers-cleaners  1370.0  32.165693  12.372635  17.0  23.0  29.0  39.0  90.0
#  Machine-op-inspct  2002.0  37.715285  12.068266  17.0  28.0  36.0  46.0  90.0
#  Other-service      3295.0  34.949621  14.521508  17.0  22.0  32.0  45.0  90.0
#  Priv-house-serv     149.0  41.724832  18.633688  17.0  24.0  40.0  57.0  81.0
#  Prof-specialty     4140.0  40.517633  12.016676  17.0  31.0  40.0  48.0  90.0
#  Protective-serv     649.0  38.953775  12.822062  17.0  29.0  36.0  47.0  90.0
# ...

# %% [markdown]
# Based on the above chart.
# a. Find which profession has the oldest workers on average -
#     Exec-managerial at 42.1692
#
# b. Which profession has its largest share of the workforce above the 75th percentile. -
#     Farming-fishing at 52.0

# %% [markdown]
# 13.Use subset and groupby to find outliers.

# %%
#Checking orginial df
df_adult.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship      sex  \
# 0        Never-married        Adm-clerical   Not-in-family     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
#Try out relationship and hours per week
df_sub_rel=df_adult.groupby('relationship').describe()['hours-per-week']
df_sub_rel.head()
# Out:
#                    count       mean        std  min    25%   50%   75%   max
# relationship
#  Husband         13193.0  44.120139  11.670203  1.0  40.00  40.0  50.0  99.0
#  Not-in-family    8305.0  40.595665  11.761193  1.0  40.00  40.0  45.0  99.0
#  Other-relative    981.0  37.006116  11.340732  1.0  33.00  40.0  40.0  99.0
#  Own-child        5068.0  33.269337  12.765355  1.0  23.00  40.0  40.0  99.0
#  Unmarried        3446.0  39.103018  10.371369  1.0  37.25  40.0  40.0  99.0

# %%
#Try out workclass and age
df_sub_wc=df_adult.groupby('workclass').describe()['age']
df_sub_wc.head(10)
# Out:
#                      count       mean        std   min    25%   50%   75%  \
# workclass
#  Federal-gov         960.0  42.590625  11.509171  17.0  34.00  43.0  51.0
#  Local-gov          2093.0  41.751075  12.272856  17.0  32.00  41.0  50.0
#  Never-worked          7.0  20.571429   4.613644  17.0  18.00  18.0  21.5
#  Private           22696.0  36.797585  12.827721  17.0  26.00  35.0  45.0
#  Self-emp-inc       1116.0  46.017025  12.553194  17.0  37.00  45.0  54.0
#  Self-emp-not-inc   2541.0  44.969697  13.338162  17.0  35.00  44.0  54.0
#  State-gov          1298.0  39.436055  12.431065  17.0  30.00  39.0  48.0
#  Without-pay          14.0  47.785714  21.075610  19.0  23.75  57.0  65.0
#
#                     max
# workclass
#  Federal-gov       90.0
#  Local-gov         90.0
#  Never-worked      30.0
#  Private           90.0
#  Self-emp-inc      84.0
#  Self-emp-not-inc  90.0
#  State-gov         81.0
#  Without-pay       72.0

# %% [markdown]
# While there are not true outliers Never-worked and Without-pay could be droped cause they are so small.

# %% [markdown]
# 14.Plot the values on a bar chart.

# %%
#Plot of Workclass and Count
df_sub_wc['count'].plot.bar()
plt.title('Workclass and count')
plt.xlabel('Workclass Type')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#Second plot using 'barh'
plt.figure()
plt.barh(y=df_sub_wc.index,
         width=df_sub_wc['count'])
plt.show()

# %% [markdown]
# 15.Merge the data using common keys.

# %%
#First df.
df_merge1 = df_adult[['age','education','occupation']].sample(50,random_state=1000)

df_merge1.head()
# Out:
#        age      education        occupation
# 27091   37   Some-college   Exec-managerial
# 993     47        HS-grad      Adm-clerical
# 12489   21   Some-college      Adm-clerical
# 6043    25   Some-college     Other-service
# 3526    29   Some-college      Adm-clerical

# %%
#Second df with education as the common column
df_merge2 = df_adult[['education','workclass','relationship']].sample(50,random_state=1000)

df_merge2.head()
# Out:
#            education   workclass    relationship
# 27091   Some-college   State-gov         Husband
# 993          HS-grad     Private         Husband
# 12489   Some-college     Private   Not-in-family
# 6043    Some-college     Private       Own-child
# 3526    Some-college     Private       Own-child

# %%
#Check the count of records
df_merge2.shape
# Out:
# (50, 3)

# %%
#Check the count of records
df_merge1.shape
# Out:
# (50, 3)

# %%
#Merge the data using education as a join on
merged = pd.merge(df_merge1,df_merge2,on='education')
#print the dataframe
merged
# Out:
#      age      education        occupation   workclass    relationship
# 0     37   Some-college   Exec-managerial   State-gov         Husband
# 1     37   Some-college   Exec-managerial     Private   Not-in-family
# 2     37   Some-college   Exec-managerial     Private       Own-child
# 3     37   Some-college   Exec-managerial     Private       Own-child
# 4     37   Some-college   Exec-managerial   Local-gov   Not-in-family
# ..   ...            ...               ...         ...             ...
# 537   33      Doctorate    Prof-specialty     Private         Husband
# 538   33      Doctorate    Prof-specialty   State-gov         Husband
# 539   33      Doctorate    Prof-specialty     Private         Husband
# 540   17           11th             Sales     Private       Own-child
# 541   30           12th      Craft-repair     Private   Not-in-family
#
# [542 rows x 5 columns]

# %%
#Drop duplicates
merged2 = pd.merge(df_merge1,df_merge2,on='education').drop_duplicates()
merged2
# Out:
#      age      education        occupation   workclass    relationship
# 0     37   Some-college   Exec-managerial   State-gov         Husband
# 1     37   Some-college   Exec-managerial     Private   Not-in-family
# 2     37   Some-college   Exec-managerial     Private       Own-child
# 4     37   Some-college   Exec-managerial   Local-gov   Not-in-family
# 5     37   Some-college   Exec-managerial     Private         Husband
# ..   ...            ...               ...         ...             ...
# 535   61      Doctorate    Prof-specialty   State-gov         Husband
# 537   33      Doctorate    Prof-specialty     Private         Husband
# 538   33      Doctorate    Prof-specialty   State-gov         Husband
# 540   17           11th             Sales     Private       Own-child
# 541   30           12th      Craft-repair     Private   Not-in-family
#
# [294 rows x 5 columns]

# %% [markdown]
# Droped like 248 duplicate records

# %% [markdown]
# #Exercise 3: Create a series and practice basic arithmetic steps

# %% [markdown]
# a.  Series 1 = 7.3, -2.5, 3.4, 1.5
#     Index 1 = 'a','c','d','e'

# %%
#Import pandas
import pandas as pd

# %%
#Variables for Series 1 and index
num1 = ([7.3,-2.5,3.4,1.5])
ind1 = (['a','c','d','e'])

#Build series called s1
series1=pd.Series(num1,index=ind1) 

#Print s1
series1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %% [markdown]
# b.  Series 2 = -2.1, 3.6, -1.5, 4, 3.1
#     Index = ‘a’, ‘c’, ‘e’, ‘f’, ‘g’

# %%
#Variables for Series 2 and index
num2 = ([-2.1, 3.6, -1.5, 4, 3.1])
ind2 = (['a', 'c', 'e', 'f', 'g'])

#Build series 2 called s2
series2=pd.Series(num2,index=ind2)

#Print series 2
series2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %% [markdown]
# c. Add Series 1 and Series 2 together and print the results

# %%
#Add series 1 and series 2
add1n2=series1+series2
#Print results

print('Total of Series 1 and Series 2:\n', add1n2)
# Out:
# Total of Series 1 and Series 2:
#  a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %% [markdown]
# d. Subtract Series 1 from Series 2 and print the results

# %%
#Subtract series 1 and series 2
sub1n2=series1-series2
#Print results
print('Total of Series 1 and Series 2:\n',sub1n2)
# Out:
# Total of Series 1 and Series 2:
#  a    9.4
# c   -6.1
# d    NaN
# e    3.0
# f    NaN
# g    NaN
# dtype: float64

# %% [markdown]
# Only indexes that match have the operation of addition or subtract performed.
